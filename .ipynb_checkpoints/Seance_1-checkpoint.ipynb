# %%
print ("Programme factoriel du nombre N")
n= int(input("Entrer le nombre N : "))
compteur = 1
f=1 
while compteur <= n :
    f=f*compteur
    compteur += 1
print ("Le factoriel de ", n, " est ", f)
# Out:
# Programme factoriel du nombre N
# Entrer le nombre N :  4
# Le factoriel de  4  est  24

# %% [markdown]
# ## Programme structuré de la calculatrice
# ![image.png](attachment:58253d13-ae42-4119-a5a7-8d14b9127b33.png)
#
# ---
# ###Description
# Cette calculatrice permet :
# - l'addion
# - la soustraction
# - la multiplication
# - et la division
# - Prochaine fonctionnalité le factoriel et fonctions logiques
# ---
# **Portez une attenion particuliere à la structure**

# %%
def add(x, y):
  return x + y

def multiply(x, y):
  return x * y

def subtract(x, y):
  return x - y

def divide(x, y):
  if y == 0:
      return "Erreur : Division par 0"
  return x / y

def get_float_input(prompt):
  while True:
      try:
          return float(input(prompt))
      except ValueError:
          print("Veuillez entrer un nombre valide.")

def main():
  operations = {
      '1': ('Addition', add),
      '2': ('Soustraction', subtract),
      '3': ('Multiplication', multiply),
      '4': ('Division', divide)
  }

  print("Sélectionnez l'opération:")
  for key, (name, _) in operations.items():
      print(f"{key}. {name}")

  while True:
      choice = input("Choisissez l'opération (1/2/3/4) : ")
      if choice in operations:
          operation_name, operation_func = operations[choice]
          x = get_float_input("Entrez le premier opérande : ")
          y = get_float_input("Entrez le deuxième opérande : ")
          
          result = operation_func(x, y)
          print(f"\nRésultat de {operation_name}: {result}")
          break
      else:
          print("Choix invalide! Veuillez réessayer.")

if __name__ == "__main__":
  main()
# Out:
# Sélectionnez l'opération:
# 1. Addition
# 2. Soustraction
# 3. Multiplication
# 4. Division
# Choisissez l'opération (1/2/3/4) :  6
# Choix invalide! Veuillez réessayer.
# Choisissez l'opération (1/2/3/4) :  2
# Entrez le premier opérande :  4
# Entrez le deuxième opérande :  7
# Résultat de Soustraction: -3.0

# %% [markdown]
# Test des listes, ensembleset tuples
